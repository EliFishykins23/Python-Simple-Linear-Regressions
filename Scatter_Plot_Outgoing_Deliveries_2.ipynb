# %% [markdown]
# <a href="https://colab.research.google.com/github/EliFishykins23/Python-Simple-Linear-Regressions/blob/main/Scatter_Plot_Outgoing_Deliveries_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install Pandas Library:

import pandas as pd

# Google Drive Library:

from google.colab import drive
drive.mount('/content/drive')

# Actual Path In Google Drive ie: /content/drive/....(File Path) :

file_path = '/content/drive/My Drive/Data_Anayltics/Simple Linear Regression_Outgoing Deliveries.xlsx'

# Read the excel
df = pd.read_excel(file_path)

# Visualization Plot Chart - Matplotlib
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.scatter(df['Distance (km)'], df[' '], marker='o', color='royalblue')

plt.title('Delivery_Time_Hr vs Distance (km)')
plt.xlabel('Delivery_Time_Hr') # Delivery_Time_Hr
plt.ylabel('Distance (km)') # Delivery_Time_Hr
plt.grid()
plt.tight_layout()
plt.show()
# Out:
# Mounted at /content/drive

# %%
# Install Pandas Library:

import pandas as pd

# Google Drive Library:

from google.colab import drive
drive.mount('/content/drive')

# Actual Path In Google Drive ie: /content/drive/....(File Path) :

file_path = '/content/drive/My Drive/Data_Anayltics/Simple Linear Regression_Outgoing Deliveries.xlsx'

# Read the excel
df = pd.read_excel(file_path)

# Visualization Plot Chart - Matplotlib
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.scatter(df['Delivery_Time_Hr'], df['Distance (km)'], marker='o', color='royalblue')

plt.title('Delivery_Time_Hr vs Distance (km)')
plt.xlabel('Delivery_Time_Hr')
plt.ylabel('Distance (km)')
plt.grid()
plt.tight_layout()
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
